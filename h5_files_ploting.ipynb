# %% [markdown]
# <a href="https://colab.research.google.com/github/DarrellSab/Colaboratory/blob/master/h5_files_ploting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install h5py

# %%
import h5py
import matplotlib.pyplot as plt

# %%
import numpy

# %%
g = h5py.File('cifar10_model.h5')

# %%
g
# Out:
# <HDF5 file "cifar10_model.h5" (mode r+)>

# %%
list(g)
# Out:
# ['conv2d_5',
#  'conv2d_6',
#  'conv2d_7',
#  'conv2d_8',
#  'dense_3',
#  'dense_4',
#  'dropout_4',
#  'dropout_5',
#  'dropout_6',
#  'flatten_2',
#  'max_pooling2d_3',
#  'max_pooling2d_4']

# %%
ds = g['dense_3/dense_3/bias:0']

# %%
ds
# Out:
# <HDF5 dataset "bias:0": shape (512,), type "<f4">

# %%
ds[...]
# Out:
# array([-0.00553354, -0.00611867, -0.00292091, -0.00284171, -0.00397103,
#        -0.00451944, -0.00494008, -0.00555356, -0.00457025, -0.00316492,
#        -0.00515284, -0.0078325 , -0.00655915, -0.00116993, -0.00639484,
#        -0.00374241, -0.00737932, -0.00523227, -0.00253735, -0.00766244,
#        -0.00812785, -0.00191072, -0.00858395, -0.00144661, -0.00101724,
#        -0.00429672, -0.00690605, -0.01008367, -0.0063614 , -0.00976886,
#        -0.00838984, -0.00228129, -0.00669146, -0.00127509, -0.00578382,
#        -0.00221835, -0.00097063, -0.00791716, -0.00320761, -0.00217273,
#        -0.00416803, -0.00834115, -0.00465011, -0.00758741, -0.0032586 ,
#        -0.00213269, -0.0063981 , -0.00770328, -0.0063221 , -0.00422888,
#        -0.00293454, -0.00218596, -0.00444012, -0.00405774, -0.00258539,
#        -0.00814237, -0.00693472, -0.00135008, -0.003104  , -0.00148841,
#        -0.0040831 , -0.00654323, -0.00426994, -0.00269658, -0.00552182,
# ...

# %%
plt.plot(ds[...])
